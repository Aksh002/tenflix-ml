# %% [markdown]
# # TenFlix v3 — Validated Pipeline Interface
#
# This notebook is intentionally thin. Authoritative model logic lives in `src/tenflix`; v1 and v2 are retained only as historical experiments.

# %%
from tenflix.config import load_config
from tenflix.pipeline import prepare_data, train_run

config = load_config('configs/v3.yaml')

# %% [markdown]
# ## Run the pipeline
#
# Uncomment these operations deliberately; full MovieLens preparation and training are batch jobs.

# %%
# prepare_data(config)
# run_path = train_run(config, mode='evaluation')
# run_path

# %%
from tenflix.artifacts import load_bundle, load_holdout
from tenflix.evaluation import evaluate
from tenflix.recommender import HybridRecommender

# bundle = load_bundle(run_path)
# report = evaluate(bundle, load_holdout(run_path))
# HybridRecommender(bundle).recommend(user_id=1, top_k=10)
